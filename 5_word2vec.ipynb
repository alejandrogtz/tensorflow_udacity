# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])

# Display the convertion from text to dictionary index
print('Sample data', data[:50])

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156, 128, 742, 477, 10572, 134, 1, 27549, 2, 1, 103, 855, 3, 1, 15068, 0, 2, 1, 151, 855, 3583, 1, 195, 11, 191, 59, 5, 6, 10742, 215, 7, 1326, 105, 455, 20, 59, 2734, 363, 7, 3676, 1]

# %%
# Lenght of the dataset converted
print ('Data lenght:',len(data))

print('Dictionary lenght:', len(dictionary))
print('Dictionary test:', dictionary['the'])
print('Dictionary test:', dictionary['of'])
print('Dictionary test:', dictionary['one'])
print('Reverse Dictionary:', len(reverse_dictionary))
print('Reverse Dictionary test:', reverse_dictionary[1])
print('Reverse Dictionary test:', reverse_dictionary[2])
print('Reverse Dictionary test:', reverse_dictionary[4])
# Out:
# Data lenght: 17005207
# Dictionary lenght: 50000
# Dictionary test: 1
# Dictionary test: 2
# Dictionary test: 4
# Reverse Dictionary: 50000
# Reverse Dictionary test: the
# Reverse Dictionary test: of
# Reverse Dictionary test: one

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'as', 'term', 'originated', 'of']

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  #'''
  #print ('Variable batch_size:',batch_size)
  #print ('Variable num_skips:',num_skips)
  for i in range(batch_size // num_skips):
    #print ('Variable i:',i)
    #print ('Variable skip_window:',skip_window)
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      #print ('Variable j:',j)    
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      #print ('Variable target:',target)
      targets_to_avoid.append(target)
      #print ('Variable buffer[skip_window]:',buffer[skip_window])
      #print ('Variable buffer[targer]:',buffer[target])
      
      #print ('Adjusted Variable buffer[skip_window]:',buffer[target])
      #print ('Adjusted Variable buffer[targer]:',buffer[skip_window])        
        
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    #print ('Variable data[data_index]:',data[data_index])
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  #'''
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

display_step =[]
display_loss =[]

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      display_step.append(step)
      display_loss.append(average_loss)        
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.669990
# Nearest to be: dervish, underpinning, darling, sanctuary, commited, blooms, findable, promptly,
# Nearest to used: animate, faculties, dulce, longsword, botticelli, margarine, phillip, transient,
# Nearest to by: lg, qa, comma, medina, portillo, popped, platinum, shoal,
# Nearest to often: brabham, tagged, overtaken, mair, lectionis, irian, consequently, cheapest,
# Nearest to has: wished, ferguson, temper, endeavor, basing, olympus, jiva, aether,
# Nearest to these: paleo, fdp, hj, bedi, stomachs, countable, harder, danmarks,
# Nearest to people: philosophical, laoghaire, arenas, banzer, foodborne, completion, northside, batmobile,
# Nearest to may: utopia, karabiners, caroline, rabat, addition, lamentations, pennsylvania, charing,
# Nearest to years: braque, nzwani, posing, dieu, wolf, commissions, calibration, schumacher,
# Nearest to it: undercut, feb, appropriated, utilize, appel, pentium, oval, highgate,
# Nearest to with: magnesium, fieldwork, fanbase, ltv, utility, unintended, nitrous, phoneme,
# Nearest to over: iniquity, keynote, stilicho, fighting, explosions, compiled, yaw, sweetened,
# Nearest to have: handbook, boycott, serving, subduction, beautifully, stadiums, asperger, exported,
# Nearest to on: soda, sibm, rotates, nutty, coached, decay, quantitatively, hamar,
# Nearest to also: schott, esters, quadrivium, uprisings, quantized, aspartic, darkened, clements,
# Nearest to an: weren, separable, suspicious, nobles, apocalyptic, detergents, subtree, exposed,
# Average loss at step 2000: 4.364965
# Average loss at step 4000: 3.863507
# Average loss at step 6000: 3.790787
# Average loss at step 8000: 3.688900
# Average loss at step 10000: 3.616148
# Nearest to be: have, malatesta, are, uncertainties, is, refer, saragossa, not,
# Nearest to used: fuss, slashing, wah, realign, phillip, faculties, bowles, transient,
# Nearest to by: was, verbs, lg, with, in, from, rensselaer, smoothly,
# Nearest to often: sometimes, also, privations, homesick, available, brabham, overtaken, amazonas,
# Nearest to has: had, was, have, is, omnivores, suiko, tsushima, larps,
# Nearest to these: many, rudolf, all, freelance, paleo, uncommonly, hj, evidences,
# Nearest to people: laoghaire, arenas, philosophical, portmanteaus, men, berg, krupp, greenish,
# Nearest to may: can, utopia, caroline, hermon, coeducational, would, hoe, walled,
# Nearest to years: braque, posing, dieu, elisabeth, tsang, commissions, subsumed, rejuvenation,
# Nearest to it: he, this, which, she, not, we, there, looney,
# Nearest to with: in, agi, from, for, by, replicate, revivals, on,
# Nearest to over: iniquity, keynote, explosions, sweetened, aol, brawl, sure, fighting,
# Nearest to have: be, had, has, are, inflexible, prominently, helsing, were,
# Nearest to on: in, northeasterly, with, affricate, at, reassure, setbacks, joshua,
# Nearest to also: sometimes, allman, it, addictive, gahan, begins, often, schott,
# Nearest to an: begun, the, kokomo, tomography, monochromatic, royce, nobles, futurists,
# Average loss at step 12000: 3.608194
# Average loss at step 14000: 3.569547
# Average loss at step 16000: 3.407423
# Average loss at step 18000: 3.457393
# Average loss at step 20000: 3.543501
# Nearest to be: have, been, by, was, is, were, being, become,
# Nearest to used: fuss, known, wah, referred, toothpaste, born, bowles, applied,
# Nearest to by: be, in, cumulative, is, was, lg, for, mariah,
# Nearest to often: sometimes, usually, it, also, generally, which, there, brabham,
# Nearest to has: had, is, have, was, does, omnivores, starbuck, bootlegged,
# Nearest to these: many, all, some, rudolf, which, scattering, socioeconomic, dominant,
# Nearest to people: men, laoghaire, panics, analogies, mesogens, krupp, arenas, glencoe,
# Nearest to may: can, would, must, could, will, might, hoe, should,
# Nearest to years: posing, braque, elisabeth, dieu, subsumed, xb, dominatrices, archibald,
# Nearest to it: he, this, there, she, they, which, not, we,
# Nearest to with: in, paley, replicate, agi, for, into, swinging, at,
# Nearest to over: explosions, objected, sweetened, parke, aol, hydroxides, down, ivo,
# Nearest to have: had, has, be, were, are, inflexible, dragoons, superconducting,
# Nearest to on: in, at, northeasterly, coached, upon, setbacks, for, since,
# Nearest to also: which, sometimes, often, harvest, never, fanpage, that, who,
# Nearest to an: elbows, begun, kokomo, tomography, detergents, expire, disguised, disfavor,
# Average loss at step 22000: 3.504365
# Average loss at step 24000: 3.491334
# Average loss at step 26000: 3.480710
# Average loss at step 28000: 3.481442
# Average loss at step 30000: 3.501221
# Nearest to be: been, have, were, refer, become, is, being, are,
# Nearest to used: known, referred, fuss, bowles, toothpaste, wah, biostatistics, applied,
# Nearest to by: in, lg, from, ga, with, tam, mustang, accumulating,
# Nearest to often: sometimes, usually, generally, there, also, still, frequently, they,
# Nearest to has: had, have, is, was, omnivores, pringle, gunfight, bootlegged,
# Nearest to these: many, some, all, several, their, such, they, which,
# Nearest to people: men, panics, laoghaire, krupp, analogies, sheedy, mesogens, supremacist,
# Nearest to may: can, would, could, must, will, might, should, cannot,
# Nearest to years: elisabeth, days, posing, subsumed, months, xb, year, archibald,
# Nearest to it: he, she, there, this, they, which, usually, not,
# Nearest to with: between, replicate, under, agi, paley, against, when, by,
# Nearest to over: down, explosions, ivo, abbess, bosses, milky, disposal, lindy,
# Nearest to have: had, has, were, are, be, inflexible, superconducting, rooks,
# Nearest to on: upon, from, in, for, northeasterly, at, through, within,
# Nearest to also: sometimes, often, which, below, now, never, largely, it,
# Nearest to an: sis, monochromatic, begun, royce, friulian, bolan, kokomo, mein,
# Average loss at step 32000: 3.501850
# Average loss at step 34000: 3.497168
# Average loss at step 36000: 3.454780
# Average loss at step 38000: 3.301051
# Average loss at step 40000: 3.428132
# Nearest to be: been, refer, have, become, were, being, is, was,
# Nearest to used: known, found, referred, sold, employed, able, bowles, fuss,
# Nearest to by: with, as, unaccustomed, lg, mustang, be, tam, ga,
# Nearest to often: sometimes, usually, generally, frequently, still, also, there, which,
# Nearest to has: had, have, is, was, beecher, pringle, federated, eleusinian,
# Nearest to these: many, some, several, all, such, both, their, they,
# Nearest to people: men, panics, laoghaire, krupp, others, those, kyd, berg,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to years: days, months, decades, subsumed, posing, dominatrices, elisabeth, seven,
# Nearest to it: he, she, there, this, which, they, but, still,
# Nearest to with: between, by, inviting, replicate, tsh, through, paley, when,
# Nearest to over: explosions, abbess, canal, ivo, objected, grape, here, down,
# Nearest to have: had, has, were, are, be, inflexible, helsing, superconducting,
# Nearest to on: upon, from, at, competencies, vieux, sada, setbacks, erowid,
# Nearest to also: which, often, sometimes, never, still, now, usually, who,
# Nearest to an: royce, flasks, tomography, kokomo, neoplatonism, elbows, indebted, abrams,
# Average loss at step 42000: 3.438283
# Average loss at step 44000: 3.453970
# Average loss at step 46000: 3.447730
# Average loss at step 48000: 3.357212
# Average loss at step 50000: 3.386995
# Nearest to be: have, were, been, was, refer, become, being, is,
# Nearest to used: known, referred, written, employed, applied, able, seen, sold,
# Nearest to by: was, cumulative, through, in, mariah, under, ga, against,
# Nearest to often: sometimes, usually, generally, frequently, still, commonly, typically, now,
# Nearest to has: had, have, is, was, does, gunfight, rooks, maas,
# Nearest to these: some, many, several, both, such, those, which, all,
# Nearest to people: men, panics, analogies, children, breakaway, mesogens, laoghaire, enterprise,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to years: days, months, decades, times, year, subsumed, hours, xb,
# Nearest to it: he, she, there, this, still, they, looney, then,
# Nearest to with: between, paley, swinging, when, agi, luzon, lachlan, andorra,
# Nearest to over: explosions, place, canal, bosses, guillain, disposal, sweetened, abbess,
# Nearest to have: had, were, has, be, are, helsing, inflexible, never,
# Nearest to on: upon, in, at, for, under, toward, through, greatest,
# Nearest to also: which, often, sometimes, now, still, largely, generally, it,
# Nearest to an: royce, flasks, indebted, the, mein, pairings, tomography, nobles,
# Average loss at step 52000: 3.437332
# Average loss at step 54000: 3.426247
# Average loss at step 56000: 3.438948
# Average loss at step 58000: 3.398621
# Average loss at step 60000: 3.391472
# Nearest to be: been, refer, have, become, being, were, are, is,
# Nearest to used: known, called, referred, seen, found, written, applied, described,
# Nearest to by: was, without, through, with, howell, tropes, cumulative, when,
# Nearest to often: sometimes, usually, generally, frequently, commonly, still, typically, also,
# Nearest to has: have, had, is, was, federated, having, pringle, yet,
# Nearest to these: many, some, several, both, those, such, which, their,
# Nearest to people: men, panics, krupp, americans, those, christians, others, children,
# Nearest to may: can, would, will, must, could, might, should, cannot,
# Nearest to years: days, decades, months, times, hours, year, subsumed, seconds,
# Nearest to it: he, there, she, this, which, still, they, clearly,
# Nearest to with: between, when, agi, replicate, paley, by, through, simplex,
# Nearest to over: through, about, down, bosses, guillain, hydroxides, mixer, cormac,
# Nearest to have: has, had, are, were, be, inflexible, resolver, unnecessarily,
# Nearest to on: upon, through, in, dassault, beyond, against, within, manor,
# Nearest to also: now, often, sometimes, below, still, subsequently, usually, generally,
# Nearest to an: tomography, royce, flasks, bolan, terracotta, unrepentant, mein, detergents,
# Average loss at step 62000: 3.241797
# Average loss at step 64000: 3.257992
# Average loss at step 66000: 3.403769
# Average loss at step 68000: 3.388980
# Average loss at step 70000: 3.357896
# Nearest to be: been, become, is, were, being, have, are, refer,
# Nearest to used: known, referred, seen, written, found, applied, sold, described,
# Nearest to by: through, mustang, cumulative, is, using, howell, be, was,
# Nearest to often: usually, sometimes, generally, commonly, typically, still, frequently, now,
# Nearest to has: had, have, is, was, malpighi, federated, blames, codons,
# Nearest to these: many, some, such, several, those, both, their, they,
# Nearest to people: men, children, members, krupp, women, americans, others, scholars,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to years: days, decades, months, hours, times, weeks, seconds, subsumed,
# Nearest to it: he, there, she, this, they, still, we, usually,
# Nearest to with: between, replicate, woz, inviting, agi, revivals, including, cinq,
# Nearest to over: about, through, bosses, down, place, explosions, mixer, guillain,
# Nearest to have: had, has, are, were, be, superconducting, receive, provide,
# Nearest to on: upon, through, in, into, northeasterly, estrogen, about, at,
# Nearest to also: often, now, still, sometimes, which, below, never, usually,
# Nearest to an: royce, tomography, flasks, indebted, steffi, detergents, bolan, diverging,
# Average loss at step 72000: 3.372818
# Average loss at step 74000: 3.348560
# Average loss at step 76000: 3.316301
# Average loss at step 78000: 3.351085
# Average loss at step 80000: 3.375182
# Nearest to be: been, have, become, refer, easily, being, were, provide,
# Nearest to used: known, referred, written, seen, found, applied, defined, sold,
# Nearest to by: through, tam, weill, cumulative, using, entheogen, tropes, be,
# Nearest to often: sometimes, usually, generally, typically, commonly, frequently, still, now,
# Nearest to has: had, have, is, was, although, since, beecher, malpighi,
# Nearest to these: several, many, both, those, such, some, various, they,
# Nearest to people: men, children, scholars, women, americans, members, others, christians,
# Nearest to may: can, would, must, could, will, might, should, cannot,
# Nearest to years: days, months, decades, hours, times, weeks, year, minutes,
# Nearest to it: he, she, there, this, they, we, itself, bothered,
# Nearest to with: between, agi, motilal, swinging, cinq, lap, when, during,
# Nearest to over: about, around, hydroxides, through, bosses, within, disposal, down,
# Nearest to have: had, has, be, are, were, inflexible, superconducting, receive,
# Nearest to on: upon, through, in, northeasterly, at, mycological, under, crispus,
# Nearest to also: now, often, which, sometimes, still, never, below, subsequently,
# Nearest to an: tomography, expire, toulon, indebted, detergents, diatomic, mein, monochromatic,
# Average loss at step 82000: 3.411390
# Average loss at step 84000: 3.413199
# Average loss at step 86000: 3.392174
# Average loss at step 88000: 3.350218
# Average loss at step 90000: 3.363911
# Nearest to be: been, have, become, being, was, is, refer, easily,
# Nearest to used: referred, known, seen, applied, called, employed, sold, designed,
# Nearest to by: through, without, cumulative, when, with, tam, from, while,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, still, also,
# Nearest to has: had, have, is, was, since, having, federated, maas,
# Nearest to these: several, many, some, such, those, both, numerous, multiple,
# Nearest to people: men, children, women, christians, man, members, americans, students,
# Nearest to may: can, will, could, would, must, might, should, cannot,
# Nearest to years: days, decades, months, hours, times, weeks, year, minutes,
# Nearest to it: he, she, this, there, they, usually, eventually, still,
# Nearest to with: between, replicate, in, swinging, by, decent, during, allein,
# Nearest to over: within, about, around, through, accented, out, hydroxides, guillain,
# Nearest to have: had, has, were, be, are, superconducting, blackpool, having,
# Nearest to on: upon, at, under, through, amplifying, northeasterly, affricate, sentimental,
# Nearest to also: now, often, sometimes, still, which, never, subsequently, below,
# Nearest to an: royce, flasks, tomography, another, mein, adolphus, digraph, diatomic,
# Average loss at step 92000: 3.394087
# Average loss at step 94000: 3.248042
# Average loss at step 96000: 3.357571
# Average loss at step 98000: 3.245618
# Average loss at step 100000: 3.355401
# Nearest to be: been, refer, being, easily, are, have, become, is,
# Nearest to used: referred, known, designed, sold, applied, found, defined, seen,
# Nearest to by: without, through, mustang, when, using, including, quranic, been,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, now, still,
# Nearest to has: had, have, is, was, since, having, federated, maas,
# Nearest to these: several, many, some, those, various, multiple, numerous, such,
# Nearest to people: men, children, students, countries, women, christians, jews, person,
# Nearest to may: can, could, must, might, would, will, should, cannot,
# Nearest to years: days, decades, months, hours, year, seconds, weeks, times,
# Nearest to it: he, she, there, this, they, we, never, which,
# Nearest to with: between, agi, in, mandaic, when, cinq, swinging, lap,
# Nearest to over: about, within, accented, kanpur, selective, out, around, hydroxides,
# Nearest to have: had, has, are, were, tend, include, be, tell,
# Nearest to on: upon, at, in, through, competencies, cx, under, supercomputers,
# Nearest to also: now, never, still, sometimes, often, below, actually, subsequently,
# Nearest to an: royce, another, tomography, bolan, hailed, spook, monochromatic, diatomic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # Tensorflow documentation tf.nn.embedding_lookup(params, ids, partition_strategy='mod', name=None, validate_indices=True)
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

display_step_cbow =[]
display_loss_cbow =[]

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    
    #print ('batch_data',batch_data)
    #print ('batch_labels',batch_labels)
    
    # Rotate batch_labels and batch_data to convert it to CBOW
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000  
      display_step_cbow.append(step)
      display_loss_cbow.append(average_loss)   
      # The average loss is an estimate of the loss over the last 2000 batches.      
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.857798
# Nearest to used: exactly, inventory, shots, flirting, thrusting, beretta, wartime, shifter,
# Nearest to into: herculaneum, glaciers, insulting, that, squaring, humoral, ribs, blower,
# Nearest to some: auger, bakersfield, pokes, allocation, domo, jarring, immigration, barrington,
# Nearest to other: arch, fringed, ddr, stylistically, chased, saturnalia, tolerance, fortify,
# Nearest to but: cygnus, quack, squirrels, guerilla, mystics, uninterested, wikiproject, obligations,
# Nearest to this: seraphim, ephemeral, green, snout, addons, counterfeit, unbelievable, anarcho,
# Nearest to it: fuses, cuisine, manus, uphill, burnt, antiproton, nacht, oren,
# Nearest to these: cantilever, crest, mus, vanessa, bracelets, sargon, manu, focus,
# Nearest to with: adaptation, cologne, placid, bonded, idi, floresiensis, homomorphism, courts,
# Nearest to more: audacity, billing, eager, centralize, daphne, gerardus, sleep, madhava,
# Nearest to to: cleaves, mitigate, attorneys, ilium, behaviorism, lentils, frost, laboratory,
# Nearest to of: branches, notate, platonic, herd, ficino, alu, beavis, manageable,
# Nearest to only: frye, extraordinary, impression, reflection, caltrans, vaporization, snapshot, sculptor,
# Nearest to system: incoming, cold, riordan, impediments, juror, parliamentarian, mainframe, transsexual,
# Nearest to been: reunion, dixon, hypopituitarism, eisenach, skookum, livelihoods, healy, leverage,
# Nearest to on: splicing, fusing, catapults, utub, wallabies, wouldn, fellows, caspar,
# Average loss at step 2000: 4.363500
# Average loss at step 4000: 3.873667
# Average loss at step 6000: 3.799952
# Average loss at step 8000: 3.755221
# Average loss at step 10000: 3.619859
# Nearest to used: known, bug, amtrak, grievous, vertebrate, cannot, dracula, melvins,
# Nearest to into: avro, herculaneum, emphasize, squaring, by, between, cluny, posing,
# Nearest to some: many, barrington, the, bakersfield, domo, all, strictest, unassigned,
# Nearest to other: ddr, arch, score, niggers, tolerance, parentage, sapporo, primitivism,
# Nearest to but: however, cygnus, cyprian, never, brooklynites, midsummer, arisen, possible,
# Nearest to this: it, which, that, the, anarcho, verb, green, scaffold,
# Nearest to it: he, this, she, there, nica, no, which, antiproton,
# Nearest to these: many, bracelets, zen, toolbox, cga, some, mus, predefined,
# Nearest to with: for, cologne, by, looney, placid, and, bebe, masking,
# Nearest to more: shrublands, landowner, archangel, triune, madhava, dramatised, zorro, longer,
# Nearest to to: from, zadar, in, petition, occured, birthdate, imagines, landmine,
# Nearest to of: and, in, occult, haus, for, cbt, unheated, hurl,
# Nearest to only: caltrans, extraordinary, snapshot, vaporization, vaccinium, exxonmobil, mathfrak, hanssen,
# Nearest to system: behalf, loan, niggers, desmo, riordan, propyl, incoming, martial,
# Nearest to been: punts, diena, hypopituitarism, optimal, senatorial, are, aetius, mounts,
# Nearest to on: in, from, and, undeniably, utub, at, receding, fps,
# Average loss at step 12000: 3.578087
# Average loss at step 14000: 3.615744
# Average loss at step 16000: 3.581253
# Average loss at step 18000: 3.570586
# Average loss at step 20000: 3.551526
# Nearest to used: known, bug, randomized, mannerisms, melvins, amtrak, cannot, seen,
# Nearest to into: from, avro, squaring, cluny, by, emphasize, using, descends,
# Nearest to some: many, these, several, all, barrington, unaffected, other, their,
# Nearest to other: modern, some, many, score, hiker, these, are, avicenna,
# Nearest to but: however, and, it, sadc, midsummer, undergoing, that, never,
# Nearest to this: it, which, green, vishnu, cuisine, verb, a, that,
# Nearest to it: he, there, this, she, which, they, antiproton, what,
# Nearest to these: some, many, their, such, they, several, zen, are,
# Nearest to with: in, by, for, placid, masking, and, quixote, sns,
# Nearest to more: less, most, very, shrublands, longer, landowner, greater, triune,
# Nearest to to: akimbo, can, not, will, zadar, ifs, for, would,
# Nearest to of: hurl, in, mishnayot, and, strom, marquesas, for, barkley,
# Nearest to only: extraordinary, vaccinium, caltrans, stationary, last, flatness, phosphate, until,
# Nearest to system: transsexual, niggers, loan, systems, vend, gacy, desmo, martial,
# Nearest to been: be, by, optimal, was, senatorial, punts, diena, murderers,
# Nearest to on: fusing, in, undeniably, utub, upon, at, hauser, receding,
# Average loss at step 22000: 3.526771
# Average loss at step 24000: 3.441176
# Average loss at step 26000: 3.422144
# Average loss at step 28000: 3.472885
# Average loss at step 30000: 3.406027
# Nearest to used: known, considered, referred, due, able, amtrak, seen, defined,
# Nearest to into: from, through, using, avro, emphasize, between, after, over,
# Nearest to some: many, these, several, barrington, most, both, all, any,
# Nearest to other: score, many, some, corners, modern, niggers, theorie, those,
# Nearest to but: however, and, although, midsummer, undergoing, are, did, missourians,
# Nearest to this: it, which, elwes, green, vishnu, the, sham, fixture,
# Nearest to it: he, there, this, she, they, which, not, justify,
# Nearest to these: some, many, several, such, they, their, all, agreeable,
# Nearest to with: by, between, lm, projekt, courthouse, masking, and, on,
# Nearest to more: less, most, longer, very, triune, greater, terrestrial, shrublands,
# Nearest to to: will, akimbo, would, zadar, can, must, for, not,
# Nearest to of: in, and, marquesas, goldfinger, hurl, towards, from, podium,
# Nearest to only: extraordinary, caltrans, vaccinium, researches, until, last, impiety, braid,
# Nearest to system: systems, loan, gacy, transsexual, vend, graal, desmo, martial,
# Nearest to been: be, become, murderers, had, were, never, senatorial, mounts,
# Nearest to on: in, upon, at, fusing, until, reservations, through, cheats,
# Average loss at step 32000: 3.415514
# Average loss at step 34000: 3.435089
# Average loss at step 36000: 3.364745
# Average loss at step 38000: 3.497856
# Average loss at step 40000: 3.439124
# Nearest to used: known, referred, considered, amtrak, due, produced, found, involved,
# Nearest to into: through, using, from, avro, over, emphasize, with, outweighs,
# Nearest to some: many, several, these, both, all, most, barrington, any,
# Nearest to other: many, various, modern, different, those, niggers, theorie, some,
# Nearest to but: however, and, although, though, that, where, it, which,
# Nearest to this: which, the, it, that, some, fixture, any, his,
# Nearest to it: he, she, there, they, this, we, not, but,
# Nearest to these: some, many, several, such, their, those, they, both,
# Nearest to with: between, disagrees, within, in, for, tsing, into, masking,
# Nearest to more: less, most, very, longer, too, greater, terrestrial, triune,
# Nearest to to: will, would, zadar, imagines, could, might, biostatistics, occured,
# Nearest to of: mishnayot, in, for, like, icbms, lgbt, entre, piled,
# Nearest to only: extraordinary, caltrans, suspend, usually, always, researches, never, addington,
# Nearest to system: systems, loan, transsexual, gacy, graal, recoil, martial, desmo,
# Nearest to been: be, become, were, was, murderers, punching, by, never,
# Nearest to on: upon, in, at, undeniably, utub, through, butch, cheques,
# Average loss at step 42000: 3.424483
# Average loss at step 44000: 3.279604
# Average loss at step 46000: 3.407883
# Average loss at step 48000: 3.429320
# Average loss at step 50000: 3.438020
# Nearest to used: known, considered, referred, produced, able, available, seen, described,
# Nearest to into: through, from, using, off, borrowers, within, gives, avro,
# Nearest to some: many, several, these, most, any, gatherer, all, barrington,
# Nearest to other: various, many, theorie, different, including, niggers, corners, mayhew,
# Nearest to but: however, and, although, though, do, missourians, while, hamas,
# Nearest to this: which, it, breeders, his, the, vishnu, elwes, divinely,
# Nearest to it: he, she, there, this, they, justify, which, sometimes,
# Nearest to these: many, some, several, such, their, those, are, various,
# Nearest to with: between, within, in, and, minotaur, by, quixote, tore,
# Nearest to more: less, most, very, longer, greater, too, shrublands, paleontologists,
# Nearest to to: would, will, akimbo, could, must, should, zadar, may,
# Nearest to of: in, for, validating, during, bare, after, redirect, hoist,
# Nearest to only: extraordinary, caltrans, considered, until, usually, researches, suspend, addington,
# Nearest to system: systems, loan, gacy, graal, recoil, scrambled, danann, martial,
# Nearest to been: be, become, was, murderers, had, were, never, senatorial,
# Nearest to on: upon, in, through, during, at, undeniably, within, reservations,
# Average loss at step 52000: 3.452148
# Average loss at step 54000: 3.430089
# Average loss at step 56000: 3.406364
# Average loss at step 58000: 3.280467
# Average loss at step 60000: 3.378921
# Nearest to used: known, considered, referred, found, able, available, defined, seen,
# Nearest to into: through, from, using, within, russo, emphasize, cluny, off,
# Nearest to some: many, several, all, these, any, both, most, the,
# Nearest to other: various, including, many, theorie, different, some, avicenna, niggers,
# Nearest to but: however, though, although, and, while, or, because, see,
# Nearest to this: which, it, that, breeders, what, divinely, the, another,
# Nearest to it: he, she, there, this, they, not, which, what,
# Nearest to these: many, some, several, those, such, their, they, both,
# Nearest to with: between, among, including, within, chordata, in, masking, through,
# Nearest to more: less, most, very, longer, shrublands, greater, rather, highly,
# Nearest to to: would, could, occured, will, zadar, predate, should, cleaves,
# Nearest to of: in, including, goldfinger, bare, tice, by, like, from,
# Nearest to only: usually, addington, still, typically, not, researches, caltrans, essentially,
# Nearest to system: systems, gacy, graal, loan, recoil, isometry, scrambled, vend,
# Nearest to been: be, become, murderers, was, were, senatorial, had, already,
# Nearest to on: in, upon, utub, through, during, butch, rejoice, within,
# Average loss at step 62000: 3.440287
# Average loss at step 64000: 3.362882
# Average loss at step 66000: 3.344954
# Average loss at step 68000: 3.382442
# Average loss at step 70000: 3.370901
# Nearest to used: known, available, considered, referred, found, described, served, seen,
# Nearest to into: through, from, using, russo, between, off, across, judaeo,
# Nearest to some: many, several, these, both, any, all, certain, most,
# Nearest to other: various, theorie, different, including, those, corners, nimh, european,
# Nearest to but: however, although, though, and, until, while, godf, since,
# Nearest to this: which, it, the, each, pity, elwes, what, breeders,
# Nearest to it: he, she, there, they, still, this, which, hubei,
# Nearest to these: some, many, such, several, those, both, there, they,
# Nearest to with: between, among, disagrees, ang, chordata, including, by, idi,
# Nearest to more: less, very, most, longer, relatively, quite, too, highly,
# Nearest to to: would, biostatistics, should, could, predate, siblings, birthdate, will,
# Nearest to of: alu, including, mishnayot, strom, barkley, in, hurl, goldfinger,
# Nearest to only: researches, last, thrive, genuinely, witnessing, suspend, until, caltrans,
# Nearest to system: systems, loan, gacy, graal, danann, isometry, scrambled, recoil,
# Nearest to been: become, be, murderers, was, punching, were, senatorial, already,
# Nearest to on: upon, through, in, at, utub, across, undeniably, towards,
# Average loss at step 72000: 3.404015
# Average loss at step 74000: 3.384403
# Average loss at step 76000: 3.350887
# Average loss at step 78000: 3.233233
# Average loss at step 80000: 3.367915
# Nearest to used: known, available, found, referred, considered, defined, able, called,
# Nearest to into: through, from, using, off, across, within, over, emphasize,
# Nearest to some: many, several, both, most, these, any, certain, various,
# Nearest to other: various, theorie, different, many, others, nimh, those, cetacean,
# Nearest to but: however, although, though, while, because, and, when, fortification,
# Nearest to this: which, it, the, some, another, vishnu, pity, what,
# Nearest to it: he, there, she, this, they, still, which, usually,
# Nearest to these: many, several, some, such, both, those, were, various,
# Nearest to with: between, among, when, disagrees, without, tsing, by, for,
# Nearest to more: less, most, very, longer, greater, too, highly, quite,
# Nearest to to: can, will, would, biostatistics, could, should, cannot, orcinus,
# Nearest to of: in, and, including, without, expiry, for, marquesas, actual,
# Nearest to only: researches, usually, suspend, not, automatically, generally, all, last,
# Nearest to system: systems, loan, gacy, scrambled, danann, graal, streams, model,
# Nearest to been: become, be, had, was, already, murderers, never, were,
# Nearest to on: upon, through, butch, utub, autodesk, catapults, off, avesta,
# Average loss at step 82000: 3.299602
# Average loss at step 84000: 3.341374
# Average loss at step 86000: 3.344738
# Average loss at step 88000: 3.316660
# Average loss at step 90000: 3.243368
# Nearest to used: available, known, referred, considered, found, defined, able, seen,
# Nearest to into: through, from, off, using, within, outweighs, authorization, emphasize,
# Nearest to some: many, several, these, certain, various, both, any, most,
# Nearest to other: various, theorie, individual, many, european, including, different, crist,
# Nearest to but: however, although, though, and, while, he, until, never,
# Nearest to this: which, it, another, the, each, that, elwes, some,
# Nearest to it: he, she, there, they, this, never, often, then,
# Nearest to these: several, some, many, those, were, both, such, all,
# Nearest to with: between, by, among, through, sns, acadia, idi, incontinence,
# Nearest to more: less, most, very, longer, rather, greater, highly, relatively,
# Nearest to to: would, will, predate, should, occured, biostatistics, cannot, scan,
# Nearest to of: in, including, and, goldfinger, virtuosic, s, although, ruthenia,
# Nearest to only: last, researches, vaughan, cusco, never, not, polytechnique, monarchists,
# Nearest to system: systems, graal, loan, famagusta, faculties, streams, gacy, dribbling,
# Nearest to been: become, be, was, already, had, begun, were, murderers,
# Nearest to on: upon, in, through, reservations, around, cheats, off, lifeless,
# Average loss at step 92000: 2.739766
# Average loss at step 94000: 3.101161
# Average loss at step 96000: 3.069066
# Average loss at step 98000: 3.220294
# Average loss at step 100000: 3.280700
# Nearest to used: known, available, referred, able, seen, applied, described, mentioned,
# Nearest to into: through, off, using, across, down, around, outweighs, authorization,
# Nearest to some: many, several, these, both, any, most, various, certain,
# Nearest to other: various, theorie, others, those, individual, hiker, nimh, many,
# Nearest to but: however, although, though, and, while, until, godf, or,
# Nearest to this: which, it, the, another, what, that, each, some,
# Nearest to it: she, he, there, this, they, itself, sometimes, usually,
# Nearest to these: many, several, some, both, those, such, their, marlow,
# Nearest to with: between, by, through, ang, tsing, among, including, jit,
# Nearest to more: less, most, very, longer, rather, highly, greater, better,
# Nearest to to: biostatistics, will, could, can, orcinus, would, must, predate,
# Nearest to of: goldfinger, alu, actual, mishnayot, vought, despite, including, and,
# Nearest to only: last, researches, babylonians, not, polytechnique, always, cusco, usually,
# Nearest to system: systems, graal, process, loan, gacy, famagusta, martial, streams,
# Nearest to been: become, be, already, were, begun, was, murderers, traditionally,
# Nearest to on: upon, butch, concerning, through, in, regarding, utub, triumvirate,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
pylab.plot(display_step,display_loss)
pylab.plot(display_step_cbow,display_loss_cbow)
pylab.show()
